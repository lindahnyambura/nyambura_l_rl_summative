# %% [markdown]
# <a href="https://colab.research.google.com/github/lindahnyambura/nyambura_l_rl_summative/blob/main/training/training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Setting up the environment**

# %%
# clone repo
# !git clone https://github.com/lindahnyambura/nyambura_l_rl_summative.git
# %cd nyambura_l_rl_summative
# !pip install -r requirements.txt

# %%
from google.colab import drive
drive.mount('/content/drive')
GDRIVE = "/content/drive/MyDrive/rl_summative_final"
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Training Policy Gradient Algorithms**

# %% [markdown]
# ### **Training PPO**

# %%
import os, sys
sys.path.append(".")

from training.pg_training import PGTrainingManager, HP_GRID

# PPO 150 k steps
mgr = PGTrainingManager(
    log_dir=f"{GDRIVE}/logs/ppo",
    model_dir=f"{GDRIVE}/models/ppo"
)
mgr.train("ppo_final", HP_GRID["ppo_final"], total_timesteps=150_000)
# Out:
# /usr/local/lib/python3.11/dist-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists
# /usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.11/dist-packages/gymnasium/envs/registration.py:636: UserWarning: WARN: Overriding environment NairobiProtestEnv-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# ============================================================
# Training PPO with config: ppo_final
# ============================================================
# Using cpu device
# Logging to /content/drive/MyDrive/rl_summative_final/logs/ppo/tensorboard/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 496      |
# |    ep_rew_mean     | -423     |
# | time/              |          |
# |    fps             | 192      |
# |    iterations      | 1        |
# |    time_elapsed    | 85       |
# |    total_timesteps | 16384    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 564         |
# |    ep_rew_mean          | -439        |
# | time/                   |             |
# |    fps                  | 176         |
# |    iterations           | 2           |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.011450822 |
# |    clip_fraction        | 0.0869      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | -0.0983     |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0278     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00594    |
# |    value_loss           | 0.0783      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 614         |
# |    ep_rew_mean          | -453        |
# | time/                   |             |
# |    fps                  | 170         |
# |    iterations           | 3           |
# |    time_elapsed         | 288         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.010804205 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | 0.491       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0255     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00803    |
# |    value_loss           | 0.0312      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 639         |
# |    ep_rew_mean          | -440        |
# | time/                   |             |
# |    fps                  | 166         |
# |    iterations           | 4           |
# |    time_elapsed         | 392         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.010259526 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | 0.532       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0226      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00982    |
# |    value_loss           | 0.0427      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 691          |
# |    ep_rew_mean          | -436         |
# | time/                   |              |
# |    fps                  | 165          |
# |    iterations           | 5            |
# |    time_elapsed         | 495          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0075180195 |
# |    clip_fraction        | 0.0709       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.55        |
# |    explained_variance   | 0.328        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.033        |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00624     |
# |    value_loss           | 0.0364       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 672         |
# |    ep_rew_mean          | -400        |
# | time/                   |             |
# |    fps                  | 163         |
# |    iterations           | 6           |
# |    time_elapsed         | 601         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.008858873 |
# |    clip_fraction        | 0.0768      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0.504       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0168     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00529    |
# |    value_loss           | 0.0248      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 672         |
# |    ep_rew_mean          | -386        |
# | time/                   |             |
# |    fps                  | 162         |
# |    iterations           | 7           |
# |    time_elapsed         | 704         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.009162655 |
# |    clip_fraction        | 0.0648      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0.759       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0206     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00372    |
# |    value_loss           | 0.0133      |
# -----------------------------------------
# Eval num_timesteps=120000, episode_reward=-604.43 +/- 218.95
# Episode length: 900.30 +/- 299.10
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 900         |
# |    mean_reward          | -604        |
# | time/                   |             |
# |    total_timesteps      | 120000      |
# | train/                  |             |
# |    approx_kl            | 0.009200641 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | 0.735       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.00738    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00595    |
# |    value_loss           | 0.0211      |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 655      |
# |    ep_rew_mean     | -373     |
# | time/              |          |
# |    fps             | 146      |
# |    iterations      | 8        |
# |    time_elapsed    | 892      |
# |    total_timesteps | 131072   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 653         |
# |    ep_rew_mean          | -378        |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 9           |
# |    time_elapsed         | 995         |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.008292887 |
# |    clip_fraction        | 0.0748      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0.801       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0114      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00521    |
# |    value_loss           | 0.029       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 641        |
# |    ep_rew_mean          | -364       |
# | time/                   |            |
# |    fps                  | 148        |
# |    iterations           | 10         |
# |    time_elapsed         | 1101       |
# |    total_timesteps      | 163840     |
# | train/                  |            |
# |    approx_kl            | 0.00822345 |
# |    clip_fraction        | 0.0587     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.46      |
# |    explained_variance   | 0.79       |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.0225     |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.00348   |
# |    value_loss           | 0.0257     |
# ----------------------------------------
# PPO ppo_final finished in 1121.8s.

# %% [markdown]
# ### **Training A2C**

# %%
import os, sys
sys.path.append(".")

from training.pg_training import PGTrainingManager, HP_GRID

# A2C 150 k steps
mgr = PGTrainingManager(
    log_dir=f"{GDRIVE}/logs/a2c",
    model_dir=f"{GDRIVE}/models/a2c"
)
mgr.train("a2c_final", HP_GRID["a2c_final"], total_timesteps=150_000)
# Out:
# /usr/local/lib/python3.11/dist-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists
# /usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.11/dist-packages/gymnasium/envs/registration.py:636: UserWarning: WARN: Overriding environment NairobiProtestEnv-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# ============================================================
# Training A2C with config: a2c_final
# ============================================================
# Using cpu device
# Logging to /content/drive/MyDrive/rl_summative_final/logs/a2c/tensorboard/A2C_1
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 399      |
# |    ep_rew_mean        | -283     |
# | time/                 |          |
# |    fps                | 184      |
# |    iterations         | 100      |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -1.61    |
# |    explained_variance | 0.97     |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.0693   |
# |    value_loss         | 0.00913  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 535      |
# |    ep_rew_mean        | -379     |
# | time/                 |          |
# |    fps                | 181      |
# |    iterations         | 200      |
# |    time_elapsed       | 88       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -1.6     |
# |    explained_variance | 0.74     |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.0471   |
# |    value_loss         | 0.00729  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 557      |
# |    ep_rew_mean        | -402     |
# | time/                 |          |
# |    fps                | 182      |
# |    iterations         | 300      |
# |    time_elapsed       | 131      |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -1.59    |
# |    explained_variance | 0.679    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.0387  |
# |    value_loss         | 0.00493  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 589      |
# |    ep_rew_mean        | -403     |
# | time/                 |          |
# |    fps                | 184      |
# |    iterations         | 400      |
# |    time_elapsed       | 173      |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -1.6     |
# |    explained_variance | 0.973    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.0615  |
# |    value_loss         | 0.00446  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 549      |
# |    ep_rew_mean        | -347     |
# | time/                 |          |
# |    fps                | 185      |
# |    iterations         | 500      |
# |    time_elapsed       | 215      |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -1.51    |
# |    explained_variance | 0.79     |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.112   |
# |    value_loss         | 0.0462   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 531      |
# |    ep_rew_mean        | -324     |
# | time/                 |          |
# |    fps                | 185      |
# |    iterations         | 600      |
# |    time_elapsed       | 258      |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -1.59    |
# |    explained_variance | 0.895    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 599      |
# |    policy_loss        | -0.0216  |
# |    value_loss         | 0.00262  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 537      |
# |    ep_rew_mean        | -320     |
# | time/                 |          |
# |    fps                | 186      |
# |    iterations         | 700      |
# |    time_elapsed       | 300      |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -1.59    |
# |    explained_variance | 0.86     |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 699      |
# |    policy_loss        | -0.017   |
# |    value_loss         | 0.00631  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 531      |
# |    ep_rew_mean        | -294     |
# | time/                 |          |
# |    fps                | 187      |
# |    iterations         | 800      |
# |    time_elapsed       | 342      |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -1.58    |
# |    explained_variance | 0.804    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.0864  |
# |    value_loss         | 0.00927  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 479      |
# |    ep_rew_mean        | -229     |
# | time/                 |          |
# |    fps                | 186      |
# |    iterations         | 900      |
# |    time_elapsed       | 385      |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -1.46    |
# |    explained_variance | 0.968    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.0136  |
# |    value_loss         | 0.00262  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 411      |
# |    ep_rew_mean        | -165     |
# | time/                 |          |
# |    fps                | 187      |
# |    iterations         | 1000     |
# |    time_elapsed       | 427      |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -1.47    |
# |    explained_variance | 0.977    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0354  |
# |    value_loss         | 0.00454  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 310      |
# |    ep_rew_mean        | -72.5    |
# | time/                 |          |
# |    fps                | 187      |
# |    iterations         | 1100     |
# |    time_elapsed       | 469      |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -1.4     |
# |    explained_variance | 0.73     |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.0502   |
# |    value_loss         | 0.0747   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 226      |
# |    ep_rew_mean        | -11.8    |
# | time/                 |          |
# |    fps                | 187      |
# |    iterations         | 1200     |
# |    time_elapsed       | 511      |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | 0.811    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.044    |
# |    value_loss         | 0.11     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 197      |
# |    ep_rew_mean        | -1.04    |
# | time/                 |          |
# |    fps                | 187      |
# |    iterations         | 1300     |
# |    time_elapsed       | 555      |
# |    total_timesteps    | 104000   |
# | train/                |          |
# |    entropy_loss       | -1.36    |
# |    explained_variance | 0.885    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.000147 |
# |    value_loss         | 0.0326   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 193      |
# |    ep_rew_mean        | 2.16     |
# | time/                 |          |
# |    fps                | 187      |
# |    iterations         | 1400     |
# |    time_elapsed       | 597      |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | -1.35    |
# |    explained_variance | 0.789    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.0961   |
# |    value_loss         | 0.133    |
# ------------------------------------
# Eval num_timesteps=120000, episode_reward=-420.64 +/- 349.74
# Episode length: 674.30 +/- 381.96
# ------------------------------------
# | eval/                 |          |
# |    mean_ep_length     | 674      |
# |    mean_reward        | -421     |
# | time/                 |          |
# |    total_timesteps    | 120000   |
# | train/                |          |
# |    entropy_loss       | -1.35    |
# |    explained_variance | 0.981    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1499     |
# |    policy_loss        | -0.0432  |
# |    value_loss         | 0.00472  |
# ------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 180      |
# |    ep_rew_mean     | 17.9     |
# | time/              |          |
# |    fps             | 176      |
# |    iterations      | 1500     |
# |    time_elapsed    | 680      |
# |    total_timesteps | 120000   |
# ---------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 148      |
# |    ep_rew_mean        | 29.8     |
# | time/                 |          |
# |    fps                | 175      |
# |    iterations         | 1600     |
# |    time_elapsed       | 728      |
# |    total_timesteps    | 128000   |
# | train/                |          |
# |    entropy_loss       | -1.34    |
# |    explained_variance | 0.952    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1599     |
# |    policy_loss        | -0.00433 |
# |    value_loss         | 0.00322  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 113      |
# |    ep_rew_mean        | 36.7     |
# | time/                 |          |
# |    fps                | 176      |
# |    iterations         | 1700     |
# |    time_elapsed       | 770      |
# |    total_timesteps    | 136000   |
# | train/                |          |
# |    entropy_loss       | -1.33    |
# |    explained_variance | 0.692    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.0694   |
# |    value_loss         | 0.0615   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 116      |
# |    ep_rew_mean        | 37.7     |
# | time/                 |          |
# |    fps                | 177      |
# |    iterations         | 1800     |
# |    time_elapsed       | 812      |
# |    total_timesteps    | 144000   |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | 0.869    |
# |    learning_rate      | 0.0003   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.0657   |
# |    value_loss         | 0.0482   |
# ------------------------------------
# A2C a2c_final finished in 844.4s.

# %% [markdown]
# ### **Training REINFORCE**

# %%
import os, sys
sys.path.append(".")

from training.pg_training import PGTrainingManager, HP_GRID

# REINFORCE 150 k steps
mgr = PGTrainingManager(
    log_dir=f"{GDRIVE}/logs/reinforce",
    model_dir=f"{GDRIVE}/models/reinforce"
)
mgr.train("reinforce_final", HP_GRID["reinforce_final"], total_timesteps=150_000)
# Out:
# /usr/local/lib/python3.11/dist-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists
# /usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.11/dist-packages/gymnasium/envs/registration.py:636: UserWarning: WARN: Overriding environment NairobiProtestEnv-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# ============================================================
# Training REINFORCE with config: reinforce_final
# ============================================================
# Using cpu device
# Logging to /content/drive/MyDrive/rl_summative_final/logs/reinforce/tensorboard/A2C_1
# ------------------------------------
# | time/                 |          |
# |    fps                | 183      |
# |    iterations         | 100      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 800      |
# | train/                |          |
# |    entropy_loss       | -1.61    |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.0761  |
# |    value_loss         | 0.0103   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 152      |
# |    iterations         | 200      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 1600     |
# | train/                |          |
# |    entropy_loss       | -1.61    |
# |    explained_variance | 0.989    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.018    |
# |    value_loss         | 0.000616 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 248      |
# |    ep_rew_mean        | -279     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 300      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 2400     |
# | train/                |          |
# |    entropy_loss       | -1.61    |
# |    explained_variance | 0.772    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.257   |
# |    value_loss         | 0.2      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 248      |
# |    ep_rew_mean        | -279     |
# | time/                 |          |
# |    fps                | 168      |
# |    iterations         | 400      |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 3200     |
# | train/                |          |
# |    entropy_loss       | -1.61    |
# |    explained_variance | 0.992    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 399      |
# |    policy_loss        | 0.014    |
# |    value_loss         | 0.00103  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 248      |
# |    ep_rew_mean        | -279     |
# | time/                 |          |
# |    fps                | 160      |
# |    iterations         | 500      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.6     |
# |    explained_variance | 0.732    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.106   |
# |    value_loss         | 0.0177   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 369      |
# |    ep_rew_mean        | -205     |
# | time/                 |          |
# |    fps                | 164      |
# |    iterations         | 600      |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 4800     |
# | train/                |          |
# |    entropy_loss       | -1.6     |
# |    explained_variance | 0.743    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 599      |
# |    policy_loss        | -0.559   |
# |    value_loss         | 0.791    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 318      |
# |    ep_rew_mean        | -199     |
# | time/                 |          |
# |    fps                | 166      |
# |    iterations         | 700      |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 5600     |
# | train/                |          |
# |    entropy_loss       | -1.6     |
# |    explained_variance | 0.994    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 699      |
# |    policy_loss        | -0.0621  |
# |    value_loss         | 0.0059   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 318      |
# |    ep_rew_mean        | -199     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 800      |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 6400     |
# | train/                |          |
# |    entropy_loss       | -1.6     |
# |    explained_variance | 0.936    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.0101  |
# |    value_loss         | 0.0011   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 318      |
# |    ep_rew_mean        | -199     |
# | time/                 |          |
# |    fps                | 164      |
# |    iterations         | 900      |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 7200     |
# | train/                |          |
# |    entropy_loss       | -1.6     |
# |    explained_variance | 0.995    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.0196  |
# |    value_loss         | 0.00113  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 550      |
# |    ep_rew_mean        | -392     |
# | time/                 |          |
# |    fps                | 166      |
# |    iterations         | 1000     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -1.59    |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0959  |
# |    value_loss         | 0.00692  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 472      |
# |    ep_rew_mean        | -329     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 1100     |
# |    time_elapsed       | 53       |
# |    total_timesteps    | 8800     |
# | train/                |          |
# |    entropy_loss       | -1.6     |
# |    explained_variance | 0.903    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.143    |
# |    value_loss         | 0.0781   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 472      |
# |    ep_rew_mean        | -329     |
# | time/                 |          |
# |    fps                | 165      |
# |    iterations         | 1200     |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 9600     |
# | train/                |          |
# |    entropy_loss       | -1.59    |
# |    explained_variance | 0.982    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.0027  |
# |    value_loss         | 0.00219  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 462      |
# |    ep_rew_mean        | -308     |
# | time/                 |          |
# |    fps                | 166      |
# |    iterations         | 1300     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 10400    |
# | train/                |          |
# |    entropy_loss       | -1.59    |
# |    explained_variance | 0.993    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.0288   |
# |    value_loss         | 0.00127  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 462      |
# |    ep_rew_mean        | -308     |
# | time/                 |          |
# |    fps                | 159      |
# |    iterations         | 1400     |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 11200    |
# | train/                |          |
# |    entropy_loss       | -1.59    |
# |    explained_variance | 0.99     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.021    |
# |    value_loss         | 0.00155  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 449      |
# |    ep_rew_mean        | -293     |
# | time/                 |          |
# |    fps                | 160      |
# |    iterations         | 1500     |
# |    time_elapsed       | 74       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -1.6     |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1499     |
# |    policy_loss        | -0.0044  |
# |    value_loss         | 0.000357 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 476      |
# |    ep_rew_mean        | -317     |
# | time/                 |          |
# |    fps                | 162      |
# |    iterations         | 1600     |
# |    time_elapsed       | 78       |
# |    total_timesteps    | 12800    |
# | train/                |          |
# |    entropy_loss       | -1.6     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.00806  |
# |    value_loss         | 0.000258 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 476      |
# |    ep_rew_mean        | -317     |
# | time/                 |          |
# |    fps                | 160      |
# |    iterations         | 1700     |
# |    time_elapsed       | 84       |
# |    total_timesteps    | 13600    |
# | train/                |          |
# |    entropy_loss       | -1.6     |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1699     |
# |    policy_loss        | -0.00507 |
# |    value_loss         | 0.000225 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 478      |
# |    ep_rew_mean        | -320     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 1800     |
# |    time_elapsed       | 88       |
# |    total_timesteps    | 14400    |
# | train/                |          |
# |    entropy_loss       | -1.59    |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1799     |
# |    policy_loss        | -0.018   |
# |    value_loss         | 0.000906 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 478      |
# |    ep_rew_mean        | -320     |
# | time/                 |          |
# |    fps                | 162      |
# |    iterations         | 1900     |
# |    time_elapsed       | 93       |
# |    total_timesteps    | 15200    |
# | train/                |          |
# |    entropy_loss       | -1.6     |
# |    explained_variance | 0.785    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.00423  |
# |    value_loss         | 0.00206  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 510      |
# |    ep_rew_mean        | -333     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 2000     |
# |    time_elapsed       | 98       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -1.58    |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.0533   |
# |    value_loss         | 0.00257  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 491      |
# |    ep_rew_mean        | -318     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 2100     |
# |    time_elapsed       | 103      |
# |    total_timesteps    | 16800    |
# | train/                |          |
# |    entropy_loss       | -1.59    |
# |    explained_variance | 0.972    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2099     |
# |    policy_loss        | -0.0584  |
# |    value_loss         | 0.00412  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 466      |
# |    ep_rew_mean        | -296     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 2200     |
# |    time_elapsed       | 107      |
# |    total_timesteps    | 17600    |
# | train/                |          |
# |    entropy_loss       | -1.53    |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2199     |
# |    policy_loss        | -0.0187  |
# |    value_loss         | 0.00139  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 499      |
# |    ep_rew_mean        | -323     |
# | time/                 |          |
# |    fps                | 162      |
# |    iterations         | 2300     |
# |    time_elapsed       | 113      |
# |    total_timesteps    | 18400    |
# | train/                |          |
# |    entropy_loss       | -1.55    |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2299     |
# |    policy_loss        | -0.00741 |
# |    value_loss         | 0.00177  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 509      |
# |    ep_rew_mean        | -343     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 2400     |
# |    time_elapsed       | 117      |
# |    total_timesteps    | 19200    |
# | train/                |          |
# |    entropy_loss       | -1.57    |
# |    explained_variance | 0.989    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.0205   |
# |    value_loss         | 0.00167  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 515      |
# |    ep_rew_mean        | -342     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 2500     |
# |    time_elapsed       | 122      |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.56    |
# |    explained_variance | 0.995    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.00078  |
# |    value_loss         | 0.000436 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 515      |
# |    ep_rew_mean        | -342     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 2600     |
# |    time_elapsed       | 127      |
# |    total_timesteps    | 20800    |
# | train/                |          |
# |    entropy_loss       | -1.55    |
# |    explained_variance | 0.994    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2599     |
# |    policy_loss        | 0.0186   |
# |    value_loss         | 0.000653 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 518      |
# |    ep_rew_mean        | -343     |
# | time/                 |          |
# |    fps                | 164      |
# |    iterations         | 2700     |
# |    time_elapsed       | 131      |
# |    total_timesteps    | 21600    |
# | train/                |          |
# |    entropy_loss       | -1.51    |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2699     |
# |    policy_loss        | -0.00484 |
# |    value_loss         | 0.000791 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 518      |
# |    ep_rew_mean        | -343     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 2800     |
# |    time_elapsed       | 136      |
# |    total_timesteps    | 22400    |
# | train/                |          |
# |    entropy_loss       | -1.53    |
# |    explained_variance | 0.985    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.0157   |
# |    value_loss         | 0.00055  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 518      |
# |    ep_rew_mean        | -343     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 2900     |
# |    time_elapsed       | 141      |
# |    total_timesteps    | 23200    |
# | train/                |          |
# |    entropy_loss       | -1.57    |
# |    explained_variance | 0.98     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.0265   |
# |    value_loss         | 0.00317  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 522      |
# |    ep_rew_mean        | -341     |
# | time/                 |          |
# |    fps                | 164      |
# |    iterations         | 3000     |
# |    time_elapsed       | 146      |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -1.59    |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.0141  |
# |    value_loss         | 0.00017  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 534      |
# |    ep_rew_mean        | -348     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 3100     |
# |    time_elapsed       | 151      |
# |    total_timesteps    | 24800    |
# | train/                |          |
# |    entropy_loss       | -1.56    |
# |    explained_variance | 0.953    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.0202  |
# |    value_loss         | 0.00226  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 555      |
# |    ep_rew_mean        | -356     |
# | time/                 |          |
# |    fps                | 164      |
# |    iterations         | 3200     |
# |    time_elapsed       | 155      |
# |    total_timesteps    | 25600    |
# | train/                |          |
# |    entropy_loss       | -1.51    |
# |    explained_variance | 0.993    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.000957 |
# |    value_loss         | 0.00102  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 555      |
# |    ep_rew_mean        | -356     |
# | time/                 |          |
# |    fps                | 164      |
# |    iterations         | 3300     |
# |    time_elapsed       | 160      |
# |    total_timesteps    | 26400    |
# | train/                |          |
# |    entropy_loss       | -1.56    |
# |    explained_variance | 0.993    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.0394   |
# |    value_loss         | 0.00261  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 556      |
# |    ep_rew_mean        | -345     |
# | time/                 |          |
# |    fps                | 164      |
# |    iterations         | 3400     |
# |    time_elapsed       | 165      |
# |    total_timesteps    | 27200    |
# | train/                |          |
# |    entropy_loss       | -1.52    |
# |    explained_variance | 0.991    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3399     |
# |    policy_loss        | -0.0245  |
# |    value_loss         | 0.0107   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 556      |
# |    ep_rew_mean        | -345     |
# | time/                 |          |
# |    fps                | 164      |
# |    iterations         | 3500     |
# |    time_elapsed       | 170      |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -1.59    |
# |    explained_variance | 0.99     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3499     |
# |    policy_loss        | -0.0213  |
# |    value_loss         | 0.0026   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 556      |
# |    ep_rew_mean        | -345     |
# | time/                 |          |
# |    fps                | 165      |
# |    iterations         | 3600     |
# |    time_elapsed       | 174      |
# |    total_timesteps    | 28800    |
# | train/                |          |
# |    entropy_loss       | -1.59    |
# |    explained_variance | 0.968    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3599     |
# |    policy_loss        | -0.00799 |
# |    value_loss         | 0.00118  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 566      |
# |    ep_rew_mean        | -352     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 3700     |
# |    time_elapsed       | 180      |
# |    total_timesteps    | 29600    |
# | train/                |          |
# |    entropy_loss       | -1.54    |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3699     |
# |    policy_loss        | -0.0111  |
# |    value_loss         | 0.000287 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 566      |
# |    ep_rew_mean        | -352     |
# | time/                 |          |
# |    fps                | 164      |
# |    iterations         | 3800     |
# |    time_elapsed       | 184      |
# |    total_timesteps    | 30400    |
# | train/                |          |
# |    entropy_loss       | -1.56    |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.00513  |
# |    value_loss         | 0.000201 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 569      |
# |    ep_rew_mean        | -357     |
# | time/                 |          |
# |    fps                | 165      |
# |    iterations         | 3900     |
# |    time_elapsed       | 188      |
# |    total_timesteps    | 31200    |
# | train/                |          |
# |    entropy_loss       | -1.59    |
# |    explained_variance | 0.977    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.00625  |
# |    value_loss         | 0.000595 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 577      |
# |    ep_rew_mean        | -356     |
# | time/                 |          |
# |    fps                | 164      |
# |    iterations         | 4000     |
# |    time_elapsed       | 195      |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -1.59    |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.00631  |
# |    value_loss         | 0.000221 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 572      |
# |    ep_rew_mean        | -351     |
# | time/                 |          |
# |    fps                | 164      |
# |    iterations         | 4100     |
# |    time_elapsed       | 199      |
# |    total_timesteps    | 32800    |
# | train/                |          |
# |    entropy_loss       | -1.55    |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4099     |
# |    policy_loss        | -0.00905 |
# |    value_loss         | 0.000259 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 572      |
# |    ep_rew_mean        | -351     |
# | time/                 |          |
# |    fps                | 165      |
# |    iterations         | 4200     |
# |    time_elapsed       | 203      |
# |    total_timesteps    | 33600    |
# | train/                |          |
# |    entropy_loss       | -1.59    |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4199     |
# |    policy_loss        | -0.0193  |
# |    value_loss         | 0.000408 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 561      |
# |    ep_rew_mean        | -338     |
# | time/                 |          |
# |    fps                | 164      |
# |    iterations         | 4300     |
# |    time_elapsed       | 209      |
# |    total_timesteps    | 34400    |
# | train/                |          |
# |    entropy_loss       | -1.59    |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.00536  |
# |    value_loss         | 0.000349 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 577      |
# |    ep_rew_mean        | -348     |
# | time/                 |          |
# |    fps                | 164      |
# |    iterations         | 4400     |
# |    time_elapsed       | 213      |
# |    total_timesteps    | 35200    |
# | train/                |          |
# |    entropy_loss       | -1.56    |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4399     |
# |    policy_loss        | -0.0136  |
# |    value_loss         | 0.000552 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 563      |
# |    ep_rew_mean        | -335     |
# | time/                 |          |
# |    fps                | 165      |
# |    iterations         | 4500     |
# |    time_elapsed       | 217      |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -1.57    |
# |    explained_variance | 0.976    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4499     |
# |    policy_loss        | -0.015   |
# |    value_loss         | 0.000855 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 569      |
# |    ep_rew_mean        | -341     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 4600     |
# |    time_elapsed       | 225      |
# |    total_timesteps    | 36800    |
# | train/                |          |
# |    entropy_loss       | -1.58    |
# |    explained_variance | 0.0903   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4599     |
# |    policy_loss        | 0.958    |
# |    value_loss         | 2.77     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 547      |
# |    ep_rew_mean        | -318     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 4700     |
# |    time_elapsed       | 229      |
# |    total_timesteps    | 37600    |
# | train/                |          |
# |    entropy_loss       | -1.58    |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4699     |
# |    policy_loss        | -0.0164  |
# |    value_loss         | 0.00021  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 547      |
# |    ep_rew_mean        | -318     |
# | time/                 |          |
# |    fps                | 164      |
# |    iterations         | 4800     |
# |    time_elapsed       | 234      |
# |    total_timesteps    | 38400    |
# | train/                |          |
# |    entropy_loss       | -1.58    |
# |    explained_variance | 0.97     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4799     |
# |    policy_loss        | 0.0202   |
# |    value_loss         | 0.000547 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 542      |
# |    ep_rew_mean        | -313     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 4900     |
# |    time_elapsed       | 239      |
# |    total_timesteps    | 39200    |
# | train/                |          |
# |    entropy_loss       | -1.58    |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4899     |
# |    policy_loss        | 0.00835  |
# |    value_loss         | 0.000245 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 528      |
# |    ep_rew_mean        | -299     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 5000     |
# |    time_elapsed       | 243      |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -1.54    |
# |    explained_variance | 0.993    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4999     |
# |    policy_loss        | -0.0166  |
# |    value_loss         | 0.000592 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 530      |
# |    ep_rew_mean        | -299     |
# | time/                 |          |
# |    fps                | 164      |
# |    iterations         | 5100     |
# |    time_elapsed       | 248      |
# |    total_timesteps    | 40800    |
# | train/                |          |
# |    entropy_loss       | -1.56    |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5099     |
# |    policy_loss        | 0.00962  |
# |    value_loss         | 0.000429 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 526      |
# |    ep_rew_mean        | -295     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 5200     |
# |    time_elapsed       | 254      |
# |    total_timesteps    | 41600    |
# | train/                |          |
# |    entropy_loss       | -1.58    |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.000143 |
# |    value_loss         | 0.00029  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 526      |
# |    ep_rew_mean        | -295     |
# | time/                 |          |
# |    fps                | 164      |
# |    iterations         | 5300     |
# |    time_elapsed       | 258      |
# |    total_timesteps    | 42400    |
# | train/                |          |
# |    entropy_loss       | -1.56    |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5299     |
# |    policy_loss        | -0.0053  |
# |    value_loss         | 0.000275 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 527      |
# |    ep_rew_mean        | -290     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 5400     |
# |    time_elapsed       | 264      |
# |    total_timesteps    | 43200    |
# | train/                |          |
# |    entropy_loss       | -1.56    |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5399     |
# |    policy_loss        | 0.0032   |
# |    value_loss         | 0.000174 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 527      |
# |    ep_rew_mean        | -289     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 5500     |
# |    time_elapsed       | 269      |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -1.51    |
# |    explained_variance | 0.995    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5499     |
# |    policy_loss        | 0.029    |
# |    value_loss         | 0.000975 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 519      |
# |    ep_rew_mean        | -281     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 5600     |
# |    time_elapsed       | 274      |
# |    total_timesteps    | 44800    |
# | train/                |          |
# |    entropy_loss       | -1.56    |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5599     |
# |    policy_loss        | -0.0228  |
# |    value_loss         | 0.00115  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 506      |
# |    ep_rew_mean        | -269     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 5700     |
# |    time_elapsed       | 279      |
# |    total_timesteps    | 45600    |
# | train/                |          |
# |    entropy_loss       | -1.57    |
# |    explained_variance | 0.628    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5699     |
# |    policy_loss        | 0.217    |
# |    value_loss         | 0.258    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 506      |
# |    ep_rew_mean        | -269     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 5800     |
# |    time_elapsed       | 284      |
# |    total_timesteps    | 46400    |
# | train/                |          |
# |    entropy_loss       | -1.53    |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5799     |
# |    policy_loss        | -0.00461 |
# |    value_loss         | 0.000386 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 499      |
# |    ep_rew_mean        | -265     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 5900     |
# |    time_elapsed       | 288      |
# |    total_timesteps    | 47200    |
# | train/                |          |
# |    entropy_loss       | -1.54    |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5899     |
# |    policy_loss        | 0.0102   |
# |    value_loss         | 0.000353 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 501      |
# |    ep_rew_mean        | -270     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 6000     |
# |    time_elapsed       | 294      |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -1.56    |
# |    explained_variance | 0.365    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5999     |
# |    policy_loss        | -0.121   |
# |    value_loss         | 0.0524   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 497      |
# |    ep_rew_mean        | -265     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 6100     |
# |    time_elapsed       | 298      |
# |    total_timesteps    | 48800    |
# | train/                |          |
# |    entropy_loss       | -1.55    |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6099     |
# |    policy_loss        | -0.0263  |
# |    value_loss         | 0.00359  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 501      |
# |    ep_rew_mean        | -268     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 6200     |
# |    time_elapsed       | 302      |
# |    total_timesteps    | 49600    |
# | train/                |          |
# |    entropy_loss       | -1.58    |
# |    explained_variance | 0.989    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6199     |
# |    policy_loss        | 0.00979  |
# |    value_loss         | 0.000747 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 498      |
# |    ep_rew_mean        | -264     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 6300     |
# |    time_elapsed       | 308      |
# |    total_timesteps    | 50400    |
# | train/                |          |
# |    entropy_loss       | -1.56    |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6299     |
# |    policy_loss        | -0.00596 |
# |    value_loss         | 0.000453 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 495      |
# |    ep_rew_mean        | -262     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 6400     |
# |    time_elapsed       | 313      |
# |    total_timesteps    | 51200    |
# | train/                |          |
# |    entropy_loss       | -1.56    |
# |    explained_variance | 0.995    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6399     |
# |    policy_loss        | -0.00207 |
# |    value_loss         | 0.000208 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 491      |
# |    ep_rew_mean        | -258     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 6500     |
# |    time_elapsed       | 317      |
# |    total_timesteps    | 52000    |
# | train/                |          |
# |    entropy_loss       | -1.56    |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6499     |
# |    policy_loss        | -0.00564 |
# |    value_loss         | 0.000199 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 490      |
# |    ep_rew_mean        | -256     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 6600     |
# |    time_elapsed       | 323      |
# |    total_timesteps    | 52800    |
# | train/                |          |
# |    entropy_loss       | -1.58    |
# |    explained_variance | 0.985    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6599     |
# |    policy_loss        | -0.0262  |
# |    value_loss         | 0.00113  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 498      |
# |    ep_rew_mean        | -260     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 6700     |
# |    time_elapsed       | 327      |
# |    total_timesteps    | 53600    |
# | train/                |          |
# |    entropy_loss       | -1.55    |
# |    explained_variance | 0.37     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6699     |
# |    policy_loss        | 0.235    |
# |    value_loss         | 0.274    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 502      |
# |    ep_rew_mean        | -260     |
# | time/                 |          |
# |    fps                | 164      |
# |    iterations         | 6800     |
# |    time_elapsed       | 331      |
# |    total_timesteps    | 54400    |
# | train/                |          |
# |    entropy_loss       | -1.57    |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6799     |
# |    policy_loss        | -0.00989 |
# |    value_loss         | 0.000162 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 503      |
# |    ep_rew_mean        | -252     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 6900     |
# |    time_elapsed       | 337      |
# |    total_timesteps    | 55200    |
# | train/                |          |
# |    entropy_loss       | -1.54    |
# |    explained_variance | 0.994    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6899     |
# |    policy_loss        | 0.0135   |
# |    value_loss         | 0.000932 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 496      |
# |    ep_rew_mean        | -247     |
# | time/                 |          |
# |    fps                | 164      |
# |    iterations         | 7000     |
# |    time_elapsed       | 341      |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -1.52    |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6999     |
# |    policy_loss        | -0.00379 |
# |    value_loss         | 0.000129 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 473      |
# |    ep_rew_mean        | -224     |
# | time/                 |          |
# |    fps                | 164      |
# |    iterations         | 7100     |
# |    time_elapsed       | 345      |
# |    total_timesteps    | 56800    |
# | train/                |          |
# |    entropy_loss       | -1.58    |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 7099     |
# |    policy_loss        | -0.00367 |
# |    value_loss         | 0.000104 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 469      |
# |    ep_rew_mean        | -221     |
# | time/                 |          |
# |    fps                | 163      |
# |    iterations         | 7200     |
# |    time_elapsed       | 351      |
# |    total_timesteps    | 57600    |
# | train/                |          |
# |    entropy_loss       | -1.51    |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 7199     |
# |    policy_loss        | 0.00579  |
# |    value_loss         | 0.000163 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 469      |
# |    ep_rew_mean        | -222     |
# | time/                 |          |
# |    fps                | 164      |
# |    iterations         | 7300     |
# |    time_elapsed       | 355      |
# |    total_timesteps    | 58400    |
# | train/                |          |
# |    entropy_loss       | -1.53    |
# |    explained_variance | 0.994    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 7299     |
# |    policy_loss        | 0.0108   |
# |    value_loss         | 0.000331 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 468      |
# |    ep_rew_mean        | -217     |
# | time/                 |          |
# |    fps                | 164      |
# |    iterations         | 7400     |
# |    time_elapsed       | 360      |
# |    total_timesteps    | 59200    |
# ...
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 16199    |
# |    policy_loss        | -0.0318  |
# |    value_loss         | 0.000485 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 505      |
# |    ep_rew_mean        | -202     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 16300    |
# |    time_elapsed       | 809      |
# |    total_timesteps    | 130400   |
# | train/                |          |
# |    entropy_loss       | -1.59    |
# |    explained_variance | 0.542    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 16299    |
# |    policy_loss        | -0.0188  |
# |    value_loss         | 0.000926 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 505      |
# |    ep_rew_mean        | -202     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 16400    |
# |    time_elapsed       | 813      |
# |    total_timesteps    | 131200   |
# | train/                |          |
# |    entropy_loss       | -1.56    |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 16399    |
# |    policy_loss        | 0.00255  |
# |    value_loss         | 8.01e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 508      |
# |    ep_rew_mean        | -205     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 16500    |
# |    time_elapsed       | 818      |
# |    total_timesteps    | 132000   |
# | train/                |          |
# |    entropy_loss       | -1.49    |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 16499    |
# |    policy_loss        | -0.00729 |
# |    value_loss         | 0.000208 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 504      |
# |    ep_rew_mean        | -201     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 16600    |
# |    time_elapsed       | 823      |
# |    total_timesteps    | 132800   |
# | train/                |          |
# |    entropy_loss       | -1.53    |
# |    explained_variance | 0.963    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 16599    |
# |    policy_loss        | -0.00476 |
# |    value_loss         | 0.00261  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 505      |
# |    ep_rew_mean        | -200     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 16700    |
# |    time_elapsed       | 827      |
# |    total_timesteps    | 133600   |
# | train/                |          |
# |    entropy_loss       | -1.58    |
# |    explained_variance | 0.988    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 16699    |
# |    policy_loss        | 0.00216  |
# |    value_loss         | 0.000482 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 506      |
# |    ep_rew_mean        | -202     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 16800    |
# |    time_elapsed       | 833      |
# |    total_timesteps    | 134400   |
# | train/                |          |
# |    entropy_loss       | -1.54    |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 16799    |
# |    policy_loss        | -0.00456 |
# |    value_loss         | 6.35e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 499      |
# |    ep_rew_mean        | -196     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 16900    |
# |    time_elapsed       | 837      |
# |    total_timesteps    | 135200   |
# | train/                |          |
# |    entropy_loss       | -1.51    |
# |    explained_variance | 0.905    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 16899    |
# |    policy_loss        | -0.0227  |
# |    value_loss         | 0.00508  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 502      |
# |    ep_rew_mean        | -199     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 17000    |
# |    time_elapsed       | 842      |
# |    total_timesteps    | 136000   |
# | train/                |          |
# |    entropy_loss       | -1.56    |
# |    explained_variance | 0.926    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 16999    |
# |    policy_loss        | 0.00432  |
# |    value_loss         | 0.000518 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 503      |
# |    ep_rew_mean        | -200     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 17100    |
# |    time_elapsed       | 849      |
# |    total_timesteps    | 136800   |
# | train/                |          |
# |    entropy_loss       | -1.55    |
# |    explained_variance | 0.991    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 17099    |
# |    policy_loss        | -0.00973 |
# |    value_loss         | 0.000401 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 497      |
# |    ep_rew_mean        | -194     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 17200    |
# |    time_elapsed       | 854      |
# |    total_timesteps    | 137600   |
# | train/                |          |
# |    entropy_loss       | -1.58    |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 17199    |
# |    policy_loss        | -0.00607 |
# |    value_loss         | 9.55e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 497      |
# |    ep_rew_mean        | -194     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 17300    |
# |    time_elapsed       | 858      |
# |    total_timesteps    | 138400   |
# | train/                |          |
# |    entropy_loss       | -1.59    |
# |    explained_variance | 0.988    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 17299    |
# |    policy_loss        | 0.00656  |
# |    value_loss         | 8.47e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 497      |
# |    ep_rew_mean        | -193     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 17400    |
# |    time_elapsed       | 863      |
# |    total_timesteps    | 139200   |
# | train/                |          |
# |    entropy_loss       | -1.59    |
# |    explained_variance | 0.992    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 17399    |
# |    policy_loss        | -0.00176 |
# |    value_loss         | 0.000569 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 495      |
# |    ep_rew_mean        | -197     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 17500    |
# |    time_elapsed       | 868      |
# |    total_timesteps    | 140000   |
# | train/                |          |
# |    entropy_loss       | -1.57    |
# |    explained_variance | 0.989    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 17499    |
# |    policy_loss        | -0.0292  |
# |    value_loss         | 0.00218  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 490      |
# |    ep_rew_mean        | -194     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 17600    |
# |    time_elapsed       | 873      |
# |    total_timesteps    | 140800   |
# | train/                |          |
# |    entropy_loss       | -1.54    |
# |    explained_variance | 0.923    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 17599    |
# |    policy_loss        | 1.96e-05 |
# |    value_loss         | 0.000542 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 496      |
# |    ep_rew_mean        | -200     |
# | time/                 |          |
# |    fps                | 160      |
# |    iterations         | 17700    |
# |    time_elapsed       | 880      |
# |    total_timesteps    | 141600   |
# | train/                |          |
# |    entropy_loss       | -1.56    |
# |    explained_variance | 0.939    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 17699    |
# |    policy_loss        | 0.0174   |
# |    value_loss         | 0.000665 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 497      |
# |    ep_rew_mean        | -203     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 17800    |
# |    time_elapsed       | 884      |
# |    total_timesteps    | 142400   |
# | train/                |          |
# |    entropy_loss       | -1.57    |
# |    explained_variance | 0.98     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 17799    |
# |    policy_loss        | -0.0475  |
# |    value_loss         | 0.00357  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 506      |
# |    ep_rew_mean        | -211     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 17900    |
# |    time_elapsed       | 888      |
# |    total_timesteps    | 143200   |
# | train/                |          |
# |    entropy_loss       | -1.55    |
# |    explained_variance | 0.989    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 17899    |
# |    policy_loss        | -0.00484 |
# |    value_loss         | 0.000593 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 515      |
# |    ep_rew_mean        | -217     |
# | time/                 |          |
# |    fps                | 160      |
# |    iterations         | 18000    |
# |    time_elapsed       | 894      |
# |    total_timesteps    | 144000   |
# | train/                |          |
# |    entropy_loss       | -1.52    |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 17999    |
# |    policy_loss        | 0.00261  |
# |    value_loss         | 0.000121 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 515      |
# |    ep_rew_mean        | -217     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 18100    |
# |    time_elapsed       | 898      |
# |    total_timesteps    | 144800   |
# | train/                |          |
# |    entropy_loss       | -1.51    |
# |    explained_variance | 0.926    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 18099    |
# |    policy_loss        | 0.0304   |
# |    value_loss         | 0.00066  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 510      |
# |    ep_rew_mean        | -210     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 18200    |
# |    time_elapsed       | 902      |
# |    total_timesteps    | 145600   |
# | train/                |          |
# |    entropy_loss       | -1.54    |
# |    explained_variance | 0.943    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 18199    |
# |    policy_loss        | -0.0564  |
# |    value_loss         | 0.00476  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 505      |
# |    ep_rew_mean        | -204     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 18300    |
# |    time_elapsed       | 908      |
# |    total_timesteps    | 146400   |
# | train/                |          |
# |    entropy_loss       | -1.51    |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 18299    |
# |    policy_loss        | -0.00401 |
# |    value_loss         | 0.000527 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 510      |
# |    ep_rew_mean        | -208     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 18400    |
# |    time_elapsed       | 913      |
# |    total_timesteps    | 147200   |
# | train/                |          |
# |    entropy_loss       | -1.58    |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 18399    |
# |    policy_loss        | -0.0225  |
# |    value_loss         | 0.000312 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 505      |
# |    ep_rew_mean        | -204     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 18500    |
# |    time_elapsed       | 917      |
# |    total_timesteps    | 148000   |
# | train/                |          |
# |    entropy_loss       | -1.54    |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 18499    |
# |    policy_loss        | 0.005    |
# |    value_loss         | 3.76e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 506      |
# |    ep_rew_mean        | -204     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 18600    |
# |    time_elapsed       | 923      |
# |    total_timesteps    | 148800   |
# | train/                |          |
# |    entropy_loss       | -1.56    |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 18599    |
# |    policy_loss        | 0.00605  |
# |    value_loss         | 0.000402 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 504      |
# |    ep_rew_mean        | -203     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 18700    |
# |    time_elapsed       | 927      |
# |    total_timesteps    | 149600   |
# | train/                |          |
# |    entropy_loss       | -1.56    |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 18699    |
# |    policy_loss        | -0.00543 |
# |    value_loss         | 0.000612 |
# ------------------------------------
# REINFORCE reinforce_final finished in 929.5s.

# %% [markdown]
# ## **Training DQN**

# %%
# ===== DQN Training =====
from training.dqn_training import DQNTrainingManager

trainer = DQNTrainingManager(
    log_dir=f"{GDRIVE}/logs/dqn_final",
    model_dir=f"{GDRIVE}/models/dqn_final"
)

trainer.train_single_config(
    "final_config",
    trainer.hyperparameter_configs["final_config"],
    total_timesteps=150_000
)
# Out:
# /usr/local/lib/python3.11/dist-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists
# /usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# ============================================================
# Training DQN with configuration: final_config
# ============================================================
# Using cpu device
# Logging to /content/drive/MyDrive/rl_summative_final/logs/dqn_final/tensorboard/DQN_final_config_0
# Eval num_timesteps=7500, episode_reward=-518.01 +/- 348.62
# Episode length: 651.90 +/- 329.63
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 652      |
# |    mean_reward      | -518     |
# | rollout/            |          |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    total_timesteps  | 7500     |
# ----------------------------------
# New best mean reward!
# Eval num_timesteps=15000, episode_reward=-400.22 +/- 360.99
# Episode length: 589.65 +/- 436.03
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 590      |
# |    mean_reward      | -400     |
# | rollout/            |          |
# |    exploration_rate | 0.864    |
# | time/               |          |
# |    total_timesteps  | 15000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.114    |
# |    n_updates        | 1749     |
# ----------------------------------
# New best mean reward!
# Eval num_timesteps=22500, episode_reward=-411.40 +/- 301.41
# Episode length: 710.20 +/- 349.61
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 710      |
# |    mean_reward      | -411     |
# | rollout/            |          |
# |    exploration_rate | 0.796    |
# | time/               |          |
# |    total_timesteps  | 22500    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.384    |
# |    n_updates        | 3624     |
# ----------------------------------
# Eval num_timesteps=30000, episode_reward=-242.44 +/- 313.39
# Episode length: 511.75 +/- 392.52
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 512      |
# |    mean_reward      | -242     |
# | rollout/            |          |
# |    exploration_rate | 0.729    |
# | time/               |          |
# |    total_timesteps  | 30000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.463    |
# |    n_updates        | 5499     |
# ----------------------------------
# New best mean reward!
# Eval num_timesteps=37500, episode_reward=-223.81 +/- 278.95
# Episode length: 472.90 +/- 392.99
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 473      |
# |    mean_reward      | -224     |
# | rollout/            |          |
# |    exploration_rate | 0.661    |
# | time/               |          |
# |    total_timesteps  | 37500    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.247    |
# |    n_updates        | 7374     |
# ----------------------------------
# New best mean reward!
# Eval num_timesteps=45000, episode_reward=-171.01 +/- 303.32
# Episode length: 372.40 +/- 377.70
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 372      |
# |    mean_reward      | -171     |
# | rollout/            |          |
# |    exploration_rate | 0.593    |
# | time/               |          |
# |    total_timesteps  | 45000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.314    |
# |    n_updates        | 9249     |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 488      |
# |    ep_rew_mean      | -284     |
# |    exploration_rate | 0.558    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 78       |
# |    time_elapsed     | 620      |
# |    total_timesteps  | 48828    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.205    |
# |    n_updates        | 10206    |
# ----------------------------------
# Eval num_timesteps=52500, episode_reward=-176.23 +/- 277.18
# Episode length: 378.40 +/- 341.87
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 378      |
# |    mean_reward      | -176     |
# | rollout/            |          |
# |    exploration_rate | 0.525    |
# | time/               |          |
# |    total_timesteps  | 52500    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.514    |
# |    n_updates        | 11124    |
# ----------------------------------
# Eval num_timesteps=60000, episode_reward=-175.20 +/- 274.87
# Episode length: 373.05 +/- 302.48
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 373      |
# |    mean_reward      | -175     |
# | rollout/            |          |
# |    exploration_rate | 0.457    |
# | time/               |          |
# |    total_timesteps  | 60000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.64     |
# |    n_updates        | 12999    |
# ----------------------------------
# Eval num_timesteps=67500, episode_reward=-191.53 +/- 237.33
# Episode length: 462.75 +/- 312.68
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 463      |
# |    mean_reward      | -192     |
# | rollout/            |          |
# |    exploration_rate | 0.389    |
# | time/               |          |
# |    total_timesteps  | 67500    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.593    |
# |    n_updates        | 14874    |
# ----------------------------------
# Eval num_timesteps=75000, episode_reward=-160.64 +/- 269.55
# Episode length: 422.55 +/- 324.89
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 423      |
# |    mean_reward      | -161     |
# | rollout/            |          |
# |    exploration_rate | 0.321    |
# | time/               |          |
# |    total_timesteps  | 75000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.507    |
# |    n_updates        | 16749    |
# ----------------------------------
# New best mean reward!
# Eval num_timesteps=82500, episode_reward=-162.72 +/- 266.83
# Episode length: 376.50 +/- 301.59
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 376      |
# |    mean_reward      | -163     |
# | rollout/            |          |
# |    exploration_rate | 0.254    |
# | time/               |          |
# |    total_timesteps  | 82500    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.42     |
# |    n_updates        | 18624    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 351      |
# |    ep_rew_mean      | -138     |
# |    exploration_rate | 0.241    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 78       |
# |    time_elapsed     | 1065     |
# |    total_timesteps  | 83911    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.423    |
# |    n_updates        | 18977    |
# ----------------------------------
# Eval num_timesteps=90000, episode_reward=-130.96 +/- 165.29
# Episode length: 338.05 +/- 177.93
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 338      |
# |    mean_reward      | -131     |
# | rollout/            |          |
# |    exploration_rate | 0.186    |
# | time/               |          |
# |    total_timesteps  | 90000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.733    |
# |    n_updates        | 20499    |
# ----------------------------------
# New best mean reward!
# Eval num_timesteps=97500, episode_reward=-104.83 +/- 232.48
# Episode length: 278.60 +/- 276.75
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 279      |
# |    mean_reward      | -105     |
# | rollout/            |          |
# |    exploration_rate | 0.118    |
# | time/               |          |
# |    total_timesteps  | 97500    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.98     |
# |    n_updates        | 22374    |
# ----------------------------------
# New best mean reward!
# Eval num_timesteps=105000, episode_reward=-98.74 +/- 217.66
# Episode length: 275.80 +/- 259.47
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 276      |
# |    mean_reward      | -98.7    |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 105000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.37     |
# |    n_updates        | 24249    |
# ----------------------------------
# New best mean reward!
# Eval num_timesteps=112500, episode_reward=-155.22 +/- 263.56
# Episode length: 422.05 +/- 365.40
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 422      |
# |    mean_reward      | -155     |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 112500   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.439    |
# |    n_updates        | 26124    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 353      |
# |    ep_rew_mean      | -128     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 82       |
# |    time_elapsed     | 1446     |
# |    total_timesteps  | 119218   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.759    |
# |    n_updates        | 27804    |
# ----------------------------------
# Eval num_timesteps=120000, episode_reward=-317.06 +/- 263.27
# Episode length: 628.05 +/- 361.29
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 628      |
# |    mean_reward      | -317     |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 120000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.396    |
# |    n_updates        | 27999    |
# ----------------------------------
# Eval num_timesteps=127500, episode_reward=-268.80 +/- 288.08
# Episode length: 512.30 +/- 354.21
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 512      |
# |    mean_reward      | -269     |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 127500   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.251    |
# |    n_updates        | 29874    |
# ----------------------------------
# Eval num_timesteps=135000, episode_reward=-375.99 +/- 307.74
# Episode length: 641.55 +/- 352.50
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 642      |
# |    mean_reward      | -376     |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 135000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.775    |
# |    n_updates        | 31749    |
# ----------------------------------
# Eval num_timesteps=142500, episode_reward=-189.67 +/- 295.80
# Episode length: 446.50 +/- 258.58
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 446      |
# |    mean_reward      | -190     |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 142500   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.77     |
# |    n_updates        | 33624    |
# ----------------------------------
# Eval num_timesteps=150000, episode_reward=-159.18 +/- 204.66
# Episode length: 309.25 +/- 267.34
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 309      |
# |    mean_reward      | -159     |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 150000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.422    |
# |    n_updates        | 35499    |
# ----------------------------------
# Training failed for final_config: not enough values to unpack (expected 5, got 4)
# (None,
#  {'error': 'not enough values to unpack (expected 5, got 4)',
#   'config_name': 'final_config'})
